# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Lab: Exploratory Data Analysis**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will work with a cleaned dataset to perform Exploratory Data Analysis or EDA.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# - Examine the structure of a dataset.
#
# - Handle missing values effectively.
#
# - Conduct summary statistics on key columns.
#
# - Analyze employment status, job satisfaction, programming language usage, and trends in remote work.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# #### Step 1: Install and Import Libraries

# %% [markdown]
# Install the necessary libraries for data manipulation and visualization.

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Collecting pandas
#   Downloading pandas-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.4.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 31.7 MB/s eta 0:00:00:00:01
# Downloading numpy-2.4.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 35.2 MB/s eta 0:00:00:00:01
# Installing collected packages: numpy, pandas
# Successfully installed numpy-2.4.3 pandas-3.0.1
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 134.2 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 162.1 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 73.1 MB/s eta 0:00:00
# Downloading pillow-12.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 167.4 MB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pillow-12.1.1 pyparsing-3.3.2
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/conda/lib/python3.12/site-packages (from seaborn) (2.4.3)
# Requirement already satisfied: pandas>=1.2 in /opt/conda/lib/python3.12/site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/conda/lib/python3.12/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %% [markdown]
# #### Step 2: Load and Preview the Dataset
# Load the dataset from the provided URL. Use df.head() to display the first few rows to get an overview of the structure.

# %%
# Load the Stack Overflow survey dataset
data_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv'
df = pd.read_csv(data_url)

# Set pandas option to display all columns
pd.set_option('display.max_columns', None)

# Display the first few rows of the dataset
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# 4                                                NaN
#
#                                              EdLevel  \
# 0                          Primary/elementary school
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3  Some college/university study without earning ...
# 4  Secondary school (e.g. American high school, G...
#
#                                            LearnCode  \
# 0                             Books / Physical media
# 1  Books / Physical media;Colleague;On the job tr...
# 2  Books / Physical media;Colleague;On the job tr...
# 3  Other online resources (e.g., videos, blogs, f...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline  \
# 0                                                NaN
# 1  Technical documentation;Blogs;Books;Written Tu...
# 2  Technical documentation;Blogs;Books;Written Tu...
# 3  Stack Overflow;How-to videos;Interactive tutorial
# 4  Technical documentation;Blogs;Written Tutorial...
#
#                                              TechDoc YearsCode YearsCodePro  \
# 0                                                NaN       NaN          NaN
# 1  API document(s) and/or SDK document(s);User gu...        20           17
# 2  API document(s) and/or SDK document(s);User gu...        37           27
# 3                                                NaN         4          NaN
# 4  API document(s) and/or SDK document(s);User gu...         9          NaN
#
#                  DevType OrgSize PurchaseInfluence BuyNewTool BuildvsBuy  \
# 0                    NaN     NaN               NaN        NaN        NaN
# 1  Developer, full-stack     NaN               NaN        NaN        NaN
# 2   Developer Experience     NaN               NaN        NaN        NaN
# 3  Developer, full-stack     NaN               NaN        NaN        NaN
# 4  Developer, full-stack     NaN               NaN        NaN        NaN
#
#   TechEndorse                                            Country Currency  \
# 0         NaN                           United States of America      NaN
# 1         NaN  United Kingdom of Great Britain and Northern I...      NaN
# 2         NaN  United Kingdom of Great Britain and Northern I...      NaN
# 3         NaN                                             Canada      NaN
# 4         NaN                                             Norway      NaN
#
#    CompTotal                             LanguageHaveWorkedWith  \
# 0        NaN                                                NaN
# 1        NaN  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2        NaN                                                 C#
# 3        NaN  C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 4        NaN            C++;HTML/CSS;JavaScript;Lua;Python;Rust
#
#                               LanguageWantToWorkWith  \
# 0                                                NaN
# 1  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                 C#
# 3  HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 4                 C++;HTML/CSS;JavaScript;Lua;Python
#
#                                      LanguageAdmired  \
# 0                                                NaN
# 1  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                 C#
# 3  HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 4                 C++;HTML/CSS;JavaScript;Lua;Python
#
#             DatabaseHaveWorkedWith      DatabaseWantToWorkWith  \
# 0                              NaN                         NaN
# 1      Dynamodb;MongoDB;PostgreSQL                  PostgreSQL
# 2       Firebase Realtime Database  Firebase Realtime Database
# 3  MongoDB;MySQL;PostgreSQL;SQLite    MongoDB;MySQL;PostgreSQL
# 4                PostgreSQL;SQLite           PostgreSQL;SQLite
#
#               DatabaseAdmired                    PlatformHaveWorkedWith  \
# 0                         NaN                                       NaN
# 1                  PostgreSQL  Amazon Web Services (AWS);Heroku;Netlify
# 2  Firebase Realtime Database                              Google Cloud
# 3    MongoDB;MySQL;PostgreSQL   Amazon Web Services (AWS);Fly.io;Heroku
# 4           PostgreSQL;SQLite                                       NaN
#
#                      PlatformWantToWorkWith  \
# 0                                       NaN
# 1  Amazon Web Services (AWS);Heroku;Netlify
# 2                              Google Cloud
# 3          Amazon Web Services (AWS);Vercel
# 4                                       NaN
#
#                             PlatformAdmired  \
# 0                                       NaN
# 1  Amazon Web Services (AWS);Heroku;Netlify
# 2                              Google Cloud
# 3                 Amazon Web Services (AWS)
# 4                                       NaN
#
#                    WebframeHaveWorkedWith            WebframeWantToWorkWith  \
# 0                                     NaN                               NaN
# 1           Express;Next.js;Node.js;React  Express;Htmx;Node.js;React;Remix
# 2                            ASP.NET CORE                      ASP.NET CORE
# 3  jQuery;Next.js;Node.js;React;WordPress      jQuery;Next.js;Node.js;React
# 4                                     NaN                               NaN
#
#                 WebframeAdmired   EmbeddedHaveWorkedWith  \
# 0                           NaN                      NaN
# 1         Express;Node.js;React                      NaN
# 2                  ASP.NET CORE              Rasberry Pi
# 3  jQuery;Next.js;Node.js;React              Rasberry Pi
# 4                           NaN  CMake;Cargo;Rasberry Pi
#
#   EmbeddedWantToWorkWith    EmbeddedAdmired  \
# 0                    NaN                NaN
# 1                    NaN                NaN
# 2            Rasberry Pi        Rasberry Pi
# 3                    NaN                NaN
# 4      CMake;Rasberry Pi  CMake;Rasberry Pi
#
#                             MiscTechHaveWorkedWith  \
# 0                                              NaN
# 1                                              NaN
# 2  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                     NumPy;Pandas;Ruff;TensorFlow
# 4                                              NaN
#
#                             MiscTechWantToWorkWith  \
# 0                                              NaN
# 1                                              NaN
# 2  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                                              NaN
# 4                                              NaN
#
#                                    MiscTechAdmired  \
# 0                                              NaN
# 1                                              NaN
# 2  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                                              NaN
# 4                                              NaN
#
#                        ToolsTechHaveWorkedWith  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                      MSBuild
# 3                               Docker;npm;Pip
# 4                                 APT;Make;npm
#
#                        ToolsTechWantToWorkWith  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                      MSBuild
# 3                        Docker;Kubernetes;npm
# 4                                     APT;Make
#
#                               ToolsTechAdmired  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                      MSBuild
# 3                                   Docker;npm
# 4                                     APT;Make
#
#           NEWCollabToolsHaveWorkedWith         NEWCollabToolsWantToWorkWith  \
# 0                                  NaN                                  NaN
# 1  PyCharm;Visual Studio Code;WebStorm  PyCharm;Visual Studio Code;WebStorm
# 2                        Visual Studio                        Visual Studio
# 3                                  NaN                                  NaN
# 4                                  Vim                                  Vim
#
#                  NEWCollabToolsAdmired        OpSysPersonal use  \
# 0                                  NaN                      NaN
# 1  PyCharm;Visual Studio Code;WebStorm            MacOS;Windows
# 2                        Visual Studio                  Windows
# 3                                  NaN                      NaN
# 4                                  Vim  Other (please specify):
#
#   OpSysProfessional use                     OfficeStackAsyncHaveWorkedWith  \
# 0                   NaN                                                NaN
# 1                 MacOS                                                NaN
# 2               Windows                                                NaN
# 3                   NaN                                                NaN
# 4                   NaN  GitHub Discussions;Markdown File;Obsidian;Stac...
#
#               OfficeStackAsyncWantToWorkWith  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4  GitHub Discussions;Markdown File;Obsidian
#
#                      OfficeStackAsyncAdmired  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4  GitHub Discussions;Markdown File;Obsidian
#
#                   OfficeStackSyncHaveWorkedWith OfficeStackSyncWantToWorkWith  \
# 0                                           NaN                           NaN
# 1                         Microsoft Teams;Slack                         Slack
# 2  Google Chat;Google Meet;Microsoft Teams;Zoom  Google Chat;Google Meet;Zoom
# 3                                           NaN                           NaN
# 4                              Discord;Whatsapp              Discord;Whatsapp
#
#          OfficeStackSyncAdmired AISearchDevHaveWorkedWith  \
# 0                           NaN                       NaN
# 1                         Slack                       NaN
# 2  Google Chat;Google Meet;Zoom                       NaN
# 3                           NaN                       NaN
# 4              Discord;Whatsapp                       NaN
#
#   AISearchDevWantToWorkWith AISearchDevAdmired  \
# 0                       NaN                NaN
# 1                       NaN                NaN
# 2                       NaN                NaN
# 3                       NaN                NaN
# 4                       NaN                NaN
#
#                                           NEWSOSites             SOVisitFreq  \
# 0  I have never visited Stack Overflow or the Sta...                     NaN
# 1  Stack Overflow for Teams (private knowledge sh...  Multiple times per day
# 2  Stack Overflow;Stack Exchange;Stack Overflow B...  Multiple times per day
# 3                                     Stack Overflow   Daily or almost daily
# 4  Stack Overflow for Teams (private knowledge sh...  Multiple times per day
#
#   SOAccount              SOPartFreq  \
# 0       NaN                     NaN
# 1       Yes  Multiple times per day
# 2       Yes  Multiple times per day
# 3        No                     NaN
# 4       Yes  Multiple times per day
#
#                                                SOHow           SOComm  \
# 0                                                NaN              NaN
# 1  Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 2  Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 3                     Quickly finding code solutions   No, not really
# 4  Quickly finding code solutions;Engage with com...  Yes, definitely
#
#                   AISelect          AISent  \
# 0                      Yes  Very favorable
# 1  No, and I don't plan to             NaN
# 2  No, and I don't plan to             NaN
# 3                      Yes  Very favorable
# 4  No, and I don't plan to             NaN
#
#                                                AIBen           AIAcc  \
# 0                              Increase productivity             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3  Increase productivity;Greater efficiency;Impro...  Somewhat trust
# 4                                                NaN             NaN
#
#                        AIComplex  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3  Bad at handling complex tasks
# 4                            NaN
#
#                                AIToolCurrently Using  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Learning about a codebase;Project planning;Wri...
# 4                                                NaN
#
#                            AIToolInterested in Using  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Testing code;Committing and reviewing code;Pre...
# 4                                                NaN
#
#   AIToolNot interested in Using  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#                           AINextMuch more integrated AINextNo change  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3  Learning about a codebase;Project planning;Wri...             NaN
# 4                                                NaN             NaN
#
#   AINextMore integrated AINextLess integrated AINextMuch less integrated  \
# 0                   NaN                   NaN                        NaN
# 1                   NaN                   NaN                        NaN
# 2                   NaN                   NaN                        NaN
# 3                   NaN                   NaN                        NaN
# 4                   NaN                   NaN                        NaN
#
#   AIThreat                                           AIEthics  \
# 0      NaN                                                NaN
# 1      NaN                                                NaN
# 2      NaN                                                NaN
# 3       No  Circulating misinformation or disinformation;M...
# 4      NaN                                                NaN
#
#                         AIChallenges TBranch                  ICorPM  WorkExp  \
# 0                                NaN      No                     NaN      NaN
# 1                                NaN     Yes  Individual contributor     17.0
# 2                                NaN      No                     NaN      NaN
# 3  Don’t trust the output or answers     NaN                     NaN      NaN
# 4                                NaN     NaN                     NaN      NaN
#
#   Knowledge_1 Knowledge_2 Knowledge_3 Knowledge_4 Knowledge_5  \
# 0         NaN         NaN         NaN         NaN         NaN
# 1       Agree    Disagree       Agree       Agree       Agree
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN
#
#                   Knowledge_6 Knowledge_7 Knowledge_8 Knowledge_9 Frequency_1  \
# 0                         NaN         NaN         NaN         NaN         NaN
# 1  Neither agree nor disagree    Disagree       Agree       Agree         NaN
# 2                         NaN         NaN         NaN         NaN         NaN
# 3                         NaN         NaN         NaN         NaN         NaN
# 4                         NaN         NaN         NaN         NaN         NaN
#
#   Frequency_2 Frequency_3 TimeSearching TimeAnswering Frustration  \
# 0         NaN         NaN           NaN           NaN         NaN
# 1         NaN         NaN           NaN           NaN         NaN
# 2         NaN         NaN           NaN           NaN         NaN
# 3         NaN         NaN           NaN           NaN         NaN
# 4         NaN         NaN           NaN           NaN         NaN
#
#   ProfessionalTech ProfessionalCloud ProfessionalQuestion Industry  \
# 0              NaN               NaN                  NaN      NaN
# 1              NaN               NaN                  NaN      NaN
# 2              NaN               NaN                  NaN      NaN
# 3              NaN               NaN                  NaN      NaN
# 4              NaN               NaN                  NaN      NaN
#
#    JobSatPoints_1  JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  \
# 0             NaN             NaN             NaN             NaN
# 1             0.0             0.0             0.0             0.0
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    JobSatPoints_7  JobSatPoints_8  JobSatPoints_9  JobSatPoints_10  \
# 0             NaN             NaN             NaN              NaN
# 1             0.0             0.0             0.0              0.0
# 2             NaN             NaN             NaN              NaN
# 3             NaN             NaN             NaN              NaN
# 4             NaN             NaN             NaN              NaN
#
#    JobSatPoints_11           SurveyLength SurveyEase  ConvertedCompYearly  \
# 0              NaN                    NaN        NaN                  NaN
# 1              0.0                    NaN        NaN                  NaN
# 2              NaN  Appropriate in length       Easy                  NaN
# 3              NaN               Too long       Easy                  NaN
# 4              NaN              Too short       Easy                  NaN
#
#    JobSat
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %% [markdown]
# #### Step 3: Handling Missing Data

# %% [markdown]
# Identify and manage missing values in critical columns such as `Employment`, `JobSat`, and `RemoteWork`. Implement a strategy to fill or drop these values, depending on the significance of the missing data.

# %%
# Check for missing values in key columns
print(df[['Employment', 'JobSat', 'RemoteWork']].isnull().sum())

# Drop rows where critical information is missing
df.dropna(subset=['Employment', 'JobSat', 'RemoteWork'], inplace=True)

# Verify cleaning
print("Missing values after cleaning:", df[['Employment', 'JobSat', 'RemoteWork']].isnull().sum().sum())
# Out:
# Employment        0
# JobSat        36311
# RemoteWork    10631
# dtype: int64
# Missing values after cleaning: 0

# %% [markdown]
# #### Step 4: Analysis of Experience and Job Satisfaction

# %% [markdown]
# Analyze the relationship between years of professional coding experience (`YearsCodePro`) and job satisfaction (`JobSat`). Summarize `YearsCodePro` and calculate median satisfaction scores based on experience ranges.
#
# - Create experience ranges for `YearsCodePro` (e.g., `0-5`, `5-10`, `10-20`, `>20` years).
#
# - Calculate the median `JobSat` for each range.
#
# - Visualize the relationship using a bar plot or similar visualization.

# %%
df['YearsCodePro'] = pd.to_numeric(df['YearsCodePro'], errors='coerce')
df.dropna(subset=['YearsCodePro'], inplace=True)
bins = [0, 5, 10, 20, float('inf')]
labels = ['0-5', '5-10', '10-20', '>20']
df['ExpRange'] = pd.cut(df['YearsCodePro'], bins=bins, labels=labels, include_lowest=True)
median_sat = df.groupby('ExpRange')['JobSatPoints_1'].median()
print(median_sat)
# Out:
# ExpRange
# 0-5       8.0
# 5-10     10.0
# 10-20    10.0
# >20      10.0
# Name: JobSatPoints_1, dtype: float64

# %% [markdown]
# #### Step 5: Visualize Job Satisfaction

# %% [markdown]
# Use a count plot to show the distribution of `JobSat` values. This provides insights into the overall satisfaction levels of respondents.

# %%
# this section is for me to better understand data distribution 
print(df['JobSat'].unique())
print(len(df))
# Out:
# [ 8.  5. 10.  9.  4.  7.  6.  3.  2.  1.  0.]
# Total rows in dataframe: 27560

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='JobSat',hue='JobSat')
plt.title('Distribution of Job Satisfaction (Scale 0-10)')
plt.xlabel('Satisfaction Score')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Step 6: Analyzing Remote Work Preferences by Job Role

# %% [markdown]
# Analyze trends in remote work based on job roles. Use the `RemoteWork` and `Employment` columns to explore preferences and examine if specific job roles prefer remote work more than others.
#
# - Use a count plot to show remote work distribution.
#
# - Cross-tabulate remote work preferences by employment type (e.g., full-time, part-time) and job roles.

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='RemoteWork')
plt.title('Remote Work Distribution')
plt.show()

remote_emp_ct = pd.crosstab(df['Employment'], df['RemoteWork'])
print(remote_emp_ct)
# Out:
# RemoteWork                                          Hybrid (some remote, some in-person)  \
# Employment
# Employed, full-time                                                                 9589
# Employed, full-time;Employed, part-time                                               47
# Employed, full-time;Independent contractor, fre...                                   797
# Employed, full-time;Independent contractor, fre...                                    52
# Employed, full-time;Independent contractor, fre...                                     0
# Employed, full-time;Independent contractor, fre...                                    41
# Employed, full-time;Independent contractor, fre...                                     3
# Employed, full-time;Not employed, and not looki...                                     0
# Employed, full-time;Not employed, but looking f...                                     8
# Employed, full-time;Not employed, but looking f...                                     0
# Employed, full-time;Not employed, but looking f...                                     4
# Employed, full-time;Not employed, but looking f...                                     0
# Employed, full-time;Not employed, but looking f...                                     0
# Employed, full-time;Not employed, but looking f...                                     0
# Employed, full-time;Retired                                                            2
# Employed, full-time;Student, full-time                                               142
# Employed, full-time;Student, full-time;Employed...                                     5
# Employed, full-time;Student, full-time;Independ...                                    24
# Employed, full-time;Student, full-time;Independ...                                     3
# Employed, full-time;Student, full-time;Not empl...                                     0
# Employed, full-time;Student, full-time;Not empl...                                     1
# Employed, full-time;Student, full-time;Not empl...                                     1
# Employed, full-time;Student, full-time;Not empl...                                     2
# Employed, full-time;Student, full-time;Not empl...                                     0
# Employed, full-time;Student, full-time;Student,...                                     1
# Employed, full-time;Student, full-time;Student,...                                     3
# Employed, full-time;Student, part-time                                               188
# Employed, full-time;Student, part-time;Employed...                                     2
# Employed, part-time                                                                  256
# Employed, part-time;Retired                                                            1
# Independent contractor, freelancer, or self-emp...                                   360
# Independent contractor, freelancer, or self-emp...                                    92
# Independent contractor, freelancer, or self-emp...                                     1
# Independent contractor, freelancer, or self-emp...                                     0
# Independent contractor, freelancer, or self-emp...                                     0
# Independent contractor, freelancer, or self-emp...                                     0
# Independent contractor, freelancer, or self-emp...                                     2
# Independent contractor, freelancer, or self-emp...                                     4
# Independent contractor, freelancer, or self-emp...                                    17
# Not employed, and not looking for work;Employed...                                     0
# Not employed, but looking for work;Employed, pa...                                     1
# Not employed, but looking for work;Independent ...                                     6
# Not employed, but looking for work;Independent ...                                     2
# Not employed, but looking for work;Independent ...                                     0
# Not employed, but looking for work;Independent ...                                     0
# Not employed, but looking for work;Independent ...                                     0
# Not employed, but looking for work;Independent ...                                     2
# Not employed, but looking for work;Independent ...                                     0
# Not employed, but looking for work;Student, par...                                     0
# Student, full-time;Employed, part-time                                               195
# Student, full-time;Independent contractor, free...                                    19
# Student, full-time;Independent contractor, free...                                    25
# Student, full-time;Independent contractor, free...                                     0
# Student, full-time;Independent contractor, free...                                     1
# Student, full-time;Not employed, but looking fo...                                     2
# Student, full-time;Student, part-time;Employed,...                                     0
# Student, part-time;Employed, part-time                                               123
#
# RemoteWork                                          In-person  Remote
# Employment
# Employed, full-time                                      4058    7786
# Employed, full-time;Employed, part-time                    15      56
# Employed, full-time;Independent contractor, fre...        219    1197
# Employed, full-time;Independent contractor, fre...          8      53
# Employed, full-time;Independent contractor, fre...          1       0
# Employed, full-time;Independent contractor, fre...         10      34
# Employed, full-time;Independent contractor, fre...          2       2
# Employed, full-time;Not employed, and not looki...          1       0
# Employed, full-time;Not employed, but looking f...          7      13
# Employed, full-time;Not employed, but looking f...          0       2
# Employed, full-time;Not employed, but looking f...          0       3
# Employed, full-time;Not employed, but looking f...          0       2
# Employed, full-time;Not employed, but looking f...          0       1
# Employed, full-time;Not employed, but looking f...          0       1
# Employed, full-time;Retired                                 1       1
# Employed, full-time;Student, full-time                     73      89
# Employed, full-time;Student, full-time;Employed...          1       3
# Employed, full-time;Student, full-time;Independ...          3      20
# Employed, full-time;Student, full-time;Independ...          1       1
# Employed, full-time;Student, full-time;Not empl...          0       1
# Employed, full-time;Student, full-time;Not empl...          0       0
# Employed, full-time;Student, full-time;Not empl...          0       0
# Employed, full-time;Student, full-time;Not empl...          1       0
# Employed, full-time;Student, full-time;Not empl...          1       1
# Employed, full-time;Student, full-time;Student,...          0       0
# Employed, full-time;Student, full-time;Student,...          0       0
# Employed, full-time;Student, part-time                    113     151
# Employed, full-time;Student, part-time;Employed...          0       3
# Employed, part-time                                        84     157
# Employed, part-time;Retired                                 0       0
# Independent contractor, freelancer, or self-emp...         49     809
# Independent contractor, freelancer, or self-emp...         14      87
# Independent contractor, freelancer, or self-emp...          0       1
# Independent contractor, freelancer, or self-emp...          0       2
# Independent contractor, freelancer, or self-emp...          0       1
# Independent contractor, freelancer, or self-emp...          0       1
# Independent contractor, freelancer, or self-emp...          0       1
# Independent contractor, freelancer, or self-emp...          0      13
# Independent contractor, freelancer, or self-emp...          3       7
# Not employed, and not looking for work;Employed...          0       1
# Not employed, but looking for work;Employed, pa...          1       3
# Not employed, but looking for work;Independent ...          1      30
# Not employed, but looking for work;Independent ...          1       6
# Not employed, but looking for work;Independent ...          0       1
# Not employed, but looking for work;Independent ...          0       1
# Not employed, but looking for work;Independent ...          0       1
# Not employed, but looking for work;Independent ...          0       4
# Not employed, but looking for work;Independent ...          0       1
# Not employed, but looking for work;Student, par...          2       0
# Student, full-time;Employed, part-time                     76      79
# Student, full-time;Independent contractor, free...          8      21
# Student, full-time;Independent contractor, free...          4      22
# Student, full-time;Independent contractor, free...          0       1
# Student, full-time;Independent contractor, free...          0       2
# Student, full-time;Not employed, but looking fo...          0       4
# Student, full-time;Student, part-time;Employed,...          0       1
# Student, part-time;Employed, part-time                     69      32

# %% [markdown]
# #### Step 7: Analyzing Programming Language Trends by Region

# %% [markdown]
# Analyze the popularity of programming languages by region. Use the `LanguageHaveWorkedWith` column to investigate which languages are most used in different regions.
#
# - Filter data by country or region.
#
# - Visualize the top programming languages by region with a bar plot or heatmap.

# %%
languages = df['LanguageHaveWorkedWith'].str.split(';', expand=True).stack().value_counts()
languages.head(10).plot(kind='bar', title='Top 10 Programming Languages')
plt.ylabel('Number of Respondents')
plt.show()

# %% [markdown]
# #### Step 8: Correlation Between Experience and Satisfaction

# %% [markdown]
# Examine how years of experience (`YearsCodePro`) correlate with job satisfaction (`JobSatPoints_1`). Use a scatter plot to visualize this relationship.

# %%
plt.figure(figsize=(20, 6))
sns.scatterplot(data=df, x='YearsCodePro', y='JobSatPoints_1', alpha=0.5)
plt.title('years of experience vs. job satisfaction')
plt.show()

# %% [markdown]
# #### Step 9: Educational Background and Employment Type

# %% [markdown]
# Explore how educational background (`EdLevel`) relates to employment type (`Employment`). Use cross-tabulation and visualizations to understand if higher education correlates with specific employment types.

# %%
ed_emp_ct = pd.crosstab(df['EdLevel'], df['Employment'])
plt.figure(figsize=(12, 8))
sns.heatmap(ed_emp_ct, annot=True, fmt='d', cmap='YlGnBu')
plt.title('Education Level vs. Employment Type')
plt.show()

# %% [markdown]
# #### Step 10: Save the Cleaned and Analyzed Dataset

# %% [markdown]
# After your analysis, save the modified dataset for further use or sharing.

# %%
## Write your code here

# %% [markdown]
# <h2>Summary</h2>

# %% [markdown]
# In this revised lab, you:
#
# - Loaded and explored the structure of the dataset.
#
# - Handled missing data effectively.
#
# - Analyzed key variables, including working hours, job satisfaction, and remote work trends.
#
# - Investigated programming language usage by region and examined the relationship between experience and satisfaction.
#
# - Used cross-tabulation to understand educational background and employment type.

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
