# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Pie Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# - In this lab, you will focus on visualizing data.
#
# - The provided dataset will be loaded into pandas for analysis.
#
# - Various pie charts will be created to:
#    - Analyze developer preferences.
#
#    - Identify technology usage trends.
#
# - The lab aims to provide insights into key variables using visual representations.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# ## Setup: Downloading and Loading the Data
# **Install the libraries**

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.12/site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %% [markdown]
# **Download and Load the Data**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Step 2: Import necessary libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("survey-data.csv")
df.to_csv('view_csv_structure.csv', index=False)

# Display the first few rows to understand the structure of the data
df.head()
# Out:
# --2026-03-09 13:25:59--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# 200 OKequest sent, awaiting response...
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv’
#
# survey-data.csv     100%[===================>] 152.13M  34.9MB/s    in 4.3s
#
# 2026-03-09 13:26:04 (35.3 MB/s) - ‘survey-data.csv’ saved [159525875/159525875]
#    ResponseId                      MainBranch  ... ConvertedCompYearly JobSat
# 0           1  I am a developer by profession  ...                 NaN    NaN
# 1           2  I am a developer by profession  ...                 NaN    NaN
# 2           3  I am a developer by profession  ...                 NaN    NaN
# 3           4           I am learning to code  ...                 NaN    NaN
# 4           5  I am a developer by profession  ...                 NaN    NaN
#
# [5 rows x 114 columns]

# %% [markdown]
# ### Task 1: Visualizing Data Composition with Pie Charts

# %% [markdown]
# ##### 1.1 Create a Pie Chart of the Top 5 Databases Respondents Want to Work With

# %% [markdown]
# In the survey data, the `DatabaseWantToWorkWith` column lists the databases that respondents wish to work with. Let’s visualize the top 5 most-desired databases in a pie chart.

# %%
top_5_db = df['DatabaseWantToWorkWith'].str.split(';').explode().value_counts().head(5)
plt.figure(figsize=(8, 6))
plt.pie(top_5_db, labels=top_5_db.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Databases Respondents want to work with')
plt.axis('equal')
plt.show()

# %% [markdown]
# The `DevType` column lists the developer types for respondents. We’ll examine the distribution by showing the top 5 developer roles in a pie chart.

# %%
top_5_dev = df['DevType'].str.split(';').explode().value_counts().head(5)
plt.figure(figsize=(8, 6))
plt.pie(top_5_dev, labels=top_5_dev.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Developer Roles')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 1.3 Create a pie chart for the operating systems used by respondents for professional use

# %% [markdown]
# The `OpSysProfessional` use column shows the operating systems developers use professionally. Let’s visualize the distribution of the top operating systems in a pie chart.

# %%
top_5_opsys = df['OpSysProfessional use'].str.split(';').explode().value_counts().head(5)
plt.figure(figsize=(8, 6))
plt.pie(top_5_opsys, labels=top_5_opsys.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Operating Systms for Professional Use')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Task 2: Additional Visualizations and Comparisons

# %% [markdown]
# ##### 2.1 Pie Chart for Top 5 Programming Languages Respondents Have Worked With

# %% [markdown]
# The `LanguageHaveWorkedWith` column contains the programming languages that respondents have experience with. We’ll plot a pie chart to display the composition of the top 5 languages.

# %%
top_5_langs = df['LanguageHaveWorkedWith'].str.split(';').explode().value_counts().head(5)
plt.figure(figsize=(8, 6))
plt.pie(top_5_langs, labels=top_5_langs.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Programming Languages Respondents have workedwith')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 2.2 Pie Chart for Top Collaboration Tools used in Professional Use

# %% [markdown]
# Using the `NEWCollabToolsHaveWorkedWith` column, we’ll identify and visualize the top collaboration tools respondents use in their professional work.

# %%
top_5_collab = df['NEWCollabToolsHaveWorkedWith'].str.split(';').explode().value_counts().head(5)
plt.figure(figsize=(8, 6))
plt.pie(top_5_collab, labels=top_5_collab.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Collaboration Tools')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Task 3: Analyzing and Interpreting Composition

# %% [markdown]
# In this task, you will create additional pie charts to analyze specific aspects of the survey data. Use `pandas` and `matplotlib` to complete each task and interpret the findings.

# %% [markdown]
# ##### 3.1 Pie Chart of `Respondents` Most Admired Programming Languages

# %% [markdown]
# The `LanguageAdmired` column lists the programming languages respondents admire most. Create a pie chart to visualize the top 5 admired languages.

# %%
top_5_admired = df['LanguageAdmired'].str.split(';').explode().value_counts().head(5)
plt.figure(figsize=(8, 6))
plt.pie(top_5_admired, labels=top_5_admired.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Most Admired Programming Languages')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 3.2 Pie Chart of Tools Used for AI Development

# %% [markdown]
# Using the `AIToolCurrently` Using column, create a pie chart to visualize the top 5 tools developers are currently using for AI development.

# %%
top_5_ai = df['AIToolCurrently Using'].str.split(';').explode().value_counts().head(5)
plt.figure(figsize=(8, 6))
plt.pie(top_5_ai, labels=top_5_ai.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 uses for AI Development')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 3.3 Pie Chart for Preferred Web Frameworks

# %% [markdown]
# The `WebframeWantToWorkWith` column includes web frameworks that respondents are interested in working with. Visualize the top 5 frameworks in a pie chart.

# %%
top_5_web = df['WebframeWantToWorkWith'].str.split(';').explode().value_counts().head(5)
plt.figure(figsize=(8, 6))
plt.pie(top_5_web, labels=top_5_web.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Web Frameworks Want to Work With')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 3.4 Pie Chart for Most Desired Embedded Technologies

# %% [markdown]
# Using the `EmbeddedWantToWorkWith` column, create a pie chart to show the top 5 most desired embedded technologies that respondents wish to work with.

# %%
top_5_embedded = df['EmbeddedWantToWorkWith'].str.split(';').explode().value_counts().head(5)
plt.figure(figsize=(8, 6))
plt.pie(top_5_embedded, labels=top_5_embedded.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Most wanted Embedded Technologies')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Create pie charts to visualize developer preferences across databases, programming languages, AI tools, and cloud platforms.
# - Identify trends in technology usage, role distribution, and tool adoption through pie charts.
# - Analyze and compare data composition across various categories to gain insights into developer preferences.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
